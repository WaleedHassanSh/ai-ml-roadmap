# %% [markdown]
# # Intro Notebook
#
# This notebook is for basic Jupyter practice. It includes simple Python code cells for variables, arithmetic, printing output, and working with lists.

# %%
x = 10
y = 20
x + y
# Out:
# 30

# %%
print("Hello, Waleed")
# Out:
# Hello, Waleed

# %%
numbers = [1, 2, 3, 4, 5]
sum(numbers)
# Out:
# 15
